# %% [markdown]
# <a href="https://colab.research.google.com/github/Grace02505/Notebook/blob/main/insurance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from matplotlib import pyplot as plt

plt.rcParams['figure.figsize'] = [7.00, 4.50]
plt.rcParams['figure.autolayout'] = True
column = ['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges']
#path = "/content/drive/MyDrive/csv file/insurance.csv"
path = "/content/drive/MyDrive/csv file/insurance.csv"
df = pd.read_csv(path)
df
print(df.head)
# Out:
# <bound method NDFrame.head of       age     sex     bmi  children smoker     region  charges  Unnamed: 7  \
# 0      19  female  27.900         0    yes  southwest    16885         NaN
# 1      18    male  33.770         1     no  southeast     1726         NaN
# 2      28    male  33.000         3     no  southeast     4449         NaN
# 3      33    male  22.705         0     no  northwest    21984         NaN
# 4      32    male  28.880         0     no  northwest     3867         NaN
# ...   ...     ...     ...       ...    ...        ...      ...         ...
# 1333   50    male  30.970         3     no  northwest    10601         NaN
# 1334   18  female  31.920         0     no  northeast     2206         NaN
# 1335   18  female  36.850         0     no  southeast     1630         NaN
# 1336   21  female  25.800         0     no  southwest     2008         NaN
# 1337   61  female  29.070         0    yes  northwest    29141         NaN
#
#       Unnamed: 8
# 0            NaN
# ...

# %%
plt.plot(df.region, df.smoker)
plt.show()

# %%
plt.plot(df.region, df.children)
plt.show()

# %%
df.info()
# we can see from this info that there is no null value in every columns so we don't have to worry handling any null value
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   age         1338 non-null   int64
#  1   sex         1338 non-null   object
#  2   bmi         1338 non-null   float64
#  3   children    1338 non-null   int64
#  4   smoker      1338 non-null   object
#  5   region      1338 non-null   object
#  6   charges     1338 non-null   int64
#  7   Unnamed: 7  0 non-null      float64
#  8   Unnamed: 8  0 non-null      float64
# dtypes: float64(3), int64(3), object(3)
# memory usage: 94.2+ KB

# %%
#checking for duplicates
df[df.duplicated(keep=False)]
# Out:
#      age   sex    bmi  children smoker     region  charges  Unnamed: 7  \
# 195   19  male  30.59         0     no  northwest     1640         NaN
# 581   19  male  30.59         0     no  northwest     1640         NaN
#
#      Unnamed: 8
# 195         NaN
# 581         NaN

# %%
#droping duplicates
df = df.drop_duplicates(keep="first")
df[df.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [age, sex, bmi, children, smoker, region, charges, Unnamed: 7, Unnamed: 8]
# Index: []

# %% [markdown]
# Handling the missing values

# %%
df.isna().sum()
#no missing values
# Out:
# age              0
# sex              0
# bmi              0
# children         0
# smoker           0
# region           0
# charges          0
# Unnamed: 7    1337
# Unnamed: 8    1337
# dtype: int64

# %%
# Getting all the unique value of the columns
for column in df.columns:
    print(f"{column} :")
    print(df[column].unique())
    print("")
# Out:
# age :
# [19 18 28 33 32 31 46 37 60 25 62 23 56 27 52 30 34 59 63 55 22 26 35 24
#  41 38 36 21 48 40 58 53 43 64 20 61 44 57 29 45 54 49 47 51 42 50 39]
#
# sex :
# ['female' 'male']
#
# bmi :
# [27.9   33.77  33.    22.705 28.88  25.74  33.44  27.74  29.83  25.84
#  26.22  26.29  34.4   39.82  42.13  24.6   30.78  23.845 40.3   35.3
#  36.005 32.4   34.1   31.92  28.025 27.72  23.085 32.775 17.385 36.3
#  35.6   26.315 28.6   28.31  36.4   20.425 32.965 20.8   36.67  39.9
#  26.6   36.63  21.78  30.8   37.05  37.3   38.665 34.77  24.53  35.2
#  35.625 33.63  28.    34.43  28.69  36.955 31.825 31.68  22.88  37.335
#  27.36  33.66  24.7   25.935 22.42  28.9   39.1   36.19  23.98  24.75
#  28.5   28.1   32.01  27.4   34.01  29.59  35.53  39.805 26.885 38.285
#  37.62  41.23  34.8   22.895 31.16  27.2   26.98  39.49  24.795 31.3
#  38.28  19.95  19.3   31.6   25.46  30.115 29.92  27.5   28.4   30.875
#  27.94  35.09  29.7   35.72  32.205 28.595 49.06  27.17  23.37  37.1
# ...

# %%
df.describe(include="all")
# Out:
#                 age   sex          bmi     children smoker     region  \
# count   1337.000000  1337  1337.000000  1337.000000   1337       1337
# unique          NaN     2          NaN          NaN      2          4
# top             NaN  male          NaN          NaN     no  southeast
# freq            NaN   675          NaN          NaN   1063        364
# mean      39.222139   NaN    30.663452     1.095737    NaN        NaN
# std       14.044333   NaN     6.100468     1.205571    NaN        NaN
# min       18.000000   NaN    15.960000     0.000000    NaN        NaN
# 25%       27.000000   NaN    26.290000     0.000000    NaN        NaN
# 50%       39.000000   NaN    30.400000     1.000000    NaN        NaN
# 75%       51.000000   NaN    34.700000     2.000000    NaN        NaN
# max       64.000000   NaN    53.130000     5.000000    NaN        NaN
#
#              charges  Unnamed: 7  Unnamed: 8
# count    1337.000000         0.0         0.0
# ...

# %% [markdown]
# *  Our oldest customer is 64 years old, with average 39 years old
#
# *  Most of our customers are male
#
# *  Our customer highest bmi is 53
# *  Most of our customers have only 1 child
#
#
# *   75% of our customers are a non-smoker
#
#
# *  25% of our customers live in Southeast region
#
# *  Our customers average charges on their insurance is 13279.121487.

# %%
df[["smoker", "bmi"]].groupby(["smoker"]).agg(["max", "min", "mean"]).reset_index()
# Out:
#   smoker    bmi
#             max     min       mean
# 0     no  53.13  15.960  30.651853
# 1    yes  52.58  17.195  30.708449

# %%
df[["smoker", "age", "sex"]].groupby(["smoker", "sex"]).agg(["max", "min", "mean", "sum"]).reset_index()
# Out:
#   smoker     sex age
#                  max min       mean    sum
# 0     no  female  64  18  39.691042  21711
# 1     no    male  64  18  39.100775  20176
# 2    yes  female  64  18  38.608696   4440
# 3    yes    male  64  18  38.446541   6113

# %%
df[["smoker", "charges"]].groupby(["smoker"]).agg(["max", "min", "mean", "sum"]).reset_index()
# Out:
#   smoker charges
#              max    min          mean      sum
# 0     no   36911   1122   8440.651929  8972413
# 1    yes   63770  12829  32050.226277  8781762

# %%
df[["sex", "charges"]].groupby(["sex"]).agg(["max", "min", "mean"]).reset_index()
# Out:
#       sex charges
#               max   min          mean
# 0  female   63770  1608  12569.584592
# 1    male   62593  1122  13974.977778

# %%
df[["region", "charges"]].groupby(["region"]).agg(["max", "min", "mean", "sum"]).reset_index()
# Out:
#       region charges
#                  max   min          mean      sum
# 0  northeast   58571  1695  13406.354938  4343659
# 1  northwest   60021  1621  12450.842593  4034073
# 2  southeast   63770  1122  14735.414835  5363691
# 3  southwest   52591  1242  12346.929231  4012752

# %%
import seaborn as sns
one = ['sex', 'smoker', 'children','region']
for i in one:
    sns.countplot(x=df[i])
    plt.show()

# %%
sns.countplot(x = 'sex', hue = 'smoker', data = df)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(x = 'children', hue = 'smoker', data = df)
# Out:
# <Axes: xlabel='children', ylabel='count'>

# %%
sns.countplot(x = 'region', hue = 'smoker', data = df)
# Out:
# <Axes: xlabel='region', ylabel='count'>

# %%
sns.boxplot(x = 'sex', y = 'charges', data = df)

print('Median charges for male:', df[df['sex'] == 'male'].charges.median())
print('Median charges for female:', df[df['sex'] == 'female'].charges.median())
# Out:
# Median charges for male: 9378.0
# Median charges for female: 9413.0

# %%
sns.histplot(data=df, x="charges", hue="smoker")
# Out:
# <Axes: xlabel='charges', ylabel='Count'>

# %%
sns.boxplot(x = 'sex', y = 'charges', data = df[(df.bmi >= 30)])
# Out:
# <Axes: xlabel='sex', ylabel='charges'>

# %%
sns.heatmap(df.corr(),annot=True)
df.corr()
# Out:
# <ipython-input-24-cf3a8f72b3fa>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)
# <ipython-input-24-cf3a8f72b3fa>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                  age       bmi  children   charges  Unnamed: 7  Unnamed: 8
# age         1.000000  0.109344  0.041536  0.298309         NaN         NaN
# bmi         0.109344  1.000000  0.012755  0.198401         NaN         NaN
# children    0.041536  0.012755  1.000000  0.067388         NaN         NaN
# charges     0.298309  0.198401  0.067388  1.000000         NaN         NaN
# ...

# %%
sns.boxplot(data=df, x="region", y="charges")
# Out:
# <Axes: xlabel='region', ylabel='charges'>

# %%
plt.figure(figsize=(10,6))
ax = sns.scatterplot(x='bmi',y='charges', data=df, hue='smoker')
ax.set_title('Scatter plot of charges and bmi')

sns.lmplot(x="bmi", y="charges", hue="smoker", data=df, height = 7)

# %%
#age < 20
sns.boxplot(x = 'smoker', y = 'charges', data = df[(df.age < 20)])
# Out:
# <Axes: xlabel='smoker', ylabel='charges'>

# %%
f, ax = plt.subplots(figsize=(16, 8))
fig = sns.boxplot(x='age', y="charges", hue='smoker', data=df)
plt.xticks(rotation=90);
