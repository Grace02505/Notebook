# %% [markdown]
# <a href="https://colab.research.google.com/github/Grace02505/Notebook/blob/main/apartment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = "/content/drive/MyDrive/csv file/apartments.csv"
df = pd.read_csv(path)
df
print(df.head)
# Out:
# <bound method NDFrame.head of       Unnamed: 0                                              title  \
# 0              0    3 Bedroom Apartment / Flat to rent in Riverside
# 1              1   3 Bedroom Apartment / Flat to rent in Kileleshwa
# 2              2        3 Bedroom Apartment / Flat to rent in Nyali
# 3              3    3 Bedroom Apartment / Flat to rent in Lavington
# 4              4   1 Bedroom Apartment / Flat to rent in Kileleshwa
# ...          ...                                                ...
# 2515        2515     3 Bedroom Apartment / Flat to rent in Kilimani
# 2516        2516        3 Bedroom Apartment / Flat to rent in Nyali
# 2517        2517  2 Bedroom Apartment / Flat to rent in Spring V...
# 2518        2518     4 Bedroom Apartment / Flat to rent in Muthaiga
# 2519        2519    2 Bedroom Apartment / Flat to rent in Westlands
#
#                                                location  bedrooms  bathrooms  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2520 entries, 0 to 2519
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  2520 non-null   int64
#  1   title       2520 non-null   object
#  2   location    2144 non-null   object
#  3   bedrooms    2520 non-null   int64
#  4   bathrooms   2520 non-null   int64
#  5   price       2520 non-null   object
#  6   rate        2520 non-null   object
# dtypes: int64(3), object(4)
# memory usage: 137.9+ KB

# %%
df[df.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, title, location, bedrooms, bathrooms, price, rate]
# Index: []

# %%
for column in df.columns:
    print(f"{column} :")
    print(df[column].unique())
    print("")
# Out:
# Unnamed: 0 :
# [   0    1    2 ... 2517 2518 2519]
#
# title :
# ['3 Bedroom Apartment / Flat to rent in Riverside'
#  '3 Bedroom Apartment / Flat to rent in Kileleshwa'
#  '3 Bedroom Apartment / Flat to rent in Nyali'
#  '3 Bedroom Apartment / Flat to rent in Lavington'
#  '1 Bedroom Apartment / Flat to rent in Kileleshwa'
#  '4 Bedroom Apartment / Flat to rent in Kahawa Wendani'
#  '2 Bedroom Apartment / Flat to rent in Kilimani'
#  '3 Bedroom Apartment / Flat to rent in Westlands'
#  '1 Bedroom Apartment / Flat to rent in Nyali'
#  '4 Bedroom Apartment / Flat to rent in Muthaiga'
#  '4 Bedroom Apartment / Flat to rent in Westlands'
#  '3 Bedroom Apartment / Flat to rent in Kikuyu'
#  '1 Bedroom Apartment / Flat to rent in Shanzu'
#  '2 Bedroom Apartment / Flat to rent in Westlands'
#  '2 Bedroom Apartment / Flat to rent in Hurlingham'
#  '2 Bedroom Apartment / Flat to rent in Kileleshwa'
#  '3 Bedroom Apartment / Flat to rent in Kilimani'
# ...

# %%
df.describe(include="all")
# Out:
#          Unnamed: 0                                        title  \
# count   2520.000000                                         2520
# unique          NaN                                           18
# top             NaN  3 Bedroom Apartment / Flat to rent in Nyali
# freq            NaN                                          252
# mean    1259.500000                                          NaN
# std      727.605662                                          NaN
# min        0.000000                                          NaN
# 25%      629.750000                                          NaN
# 50%     1259.500000                                          NaN
# 75%     1889.250000                                          NaN
# max     2519.000000                                          NaN
#
#                    location     bedrooms    bathrooms    price       rate
# count                  2144  2520.000000  2520.000000     2520       2520
# ...

# %%
import seaborn as sns
one = ['bedrooms', 'bathrooms', 'location']
for i in one:
    sns.countplot(x=df[i])
    plt.show()

# %%
sns.histplot(df['price'])
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
#distribution by location
sns.pairplot(df[['price', 'bedrooms', 'bathrooms', 'rate', 'location']], hue='location')
